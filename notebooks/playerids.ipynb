# %%
import pandas as pd

# %%
pi = pd.read_csv("../data/mlb-playerids.csv")
pi = pi.loc[:, ~pi.columns.str.contains("^Unnamed")]
pi = pi.drop_duplicates("MLBID")
pi.to_csv("../data/mlb-playerids.csv", index=False)

# %%
# this will allow me to use get() and input a id and get a player name to input into my data frame
pi_dict = dict(zip(pi["MLBID"], pi["PLAYERNAME"]))
