# %%
import pandas as pd
import os
import pybaseball as pyb

# %%
pi = pd.read_csv("../data/mlb-playerids.csv")
pi.tail()
# Out:
#        Unnamed: 0   MLBID           PLAYERNAME
# 18191           0  815204         Justin Barry
# 18192           0  829059  Johan De Los Santos
# 18193           0  809092            Murf Gray
# 18194           0  808115       Bryan Martinez
# 18195           0  815814        Billy Carlson

# %%
pi = pi.loc[:, ~pi.columns.str.contains("^Unnamed")]
