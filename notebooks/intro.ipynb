# %%
import pandas as pd
import os
import pybaseball as pyb

# %%
pi = pd.read_csv("../data/mlb-playerids.csv")
pi.tail()
# Out:
#         MLBID           PLAYERNAME
# 16109  815204         Justin Barry
# 16110  829059  Johan De Los Santos
# 16111  809092            Murf Gray
# 16112  808115       Bryan Martinez
# 16113  815814        Billy Carlson

# %%
pi = pi.loc[:, ~pi.columns.str.contains("^Unnamed")]

# %%
pi = pi.drop_duplicates("MLBID")
pi.to_csv("../data/mlb-playerids.csv", index=False)
