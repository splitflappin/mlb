# %%
import pandas as pd

# %%
s25 = pd.read_csv("../data/season2025.csv")
s25.head()
# Out:
# /var/folders/7c/6r6rdvjn51lcnkrj5czgk3qh0000gn/T/ipykernel_9820/3434693880.py:1: DtypeWarning: Columns (0: pitch_type, 1: pitch_name, 2: if_fielding_alignment, 3: of_fielding_alignment) have mixed types. Specify dtype option on import or set low_memory=False.
#   s25 = pd.read_csv("../data/season2025.csv")
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FS  2025-11-01           92.1          -2.02           5.15
# 1         CU  2025-11-01           80.3          -1.70           5.45
# 2         FC  2025-11-01           92.8          -1.91           5.24
# 3         FS  2025-11-01           90.9          -1.97           5.26
# 4         FS  2025-11-01           90.8          -2.02           5.27
#
#            player_name  batter  pitcher                     events  \
# 0  Yamamoto, Yoshinobu  672386   808967  grounded_into_double_play
# 1  Yamamoto, Yoshinobu  672386   808967                        NaN
# ...
